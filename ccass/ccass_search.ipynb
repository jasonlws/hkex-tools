# %%
import sys
import re
import requests
import urllib.parse
import json
import pandas as pd
import argparse
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

def validate_arg_code(code):
    if code.isdigit() and len(code) <= 5:
        return code
    else:
        print('Invalid Stock Code')
        raise ValueError('Invalid Stock Code')

def validate_arg_start(start):
    pattern_str = r'^\d{4}/\d{2}/\d{2}$'
    try:
        if re.match(pattern_str, start) and bool(datetime.strptime(start, '%Y/%m/%d')):
            return start
        else:
            raise ValueError('Invalid Shareholding Start Date')
    except ValueError:
        print('Invalid Shareholding Start Date')
        raise

def validate_arg_end(end):
    pattern_str = r'^\d{4}/\d{2}/\d{2}$'
    try:
        if re.match(pattern_str, end) and bool(datetime.strptime(end, '%Y/%m/%d')):
            return end
        else:
            raise ValueError('Invalid Shareholding End Date')
    except ValueError:
        print('Invalid Shareholding End Date')
        raise

def searchsdw(today, txtShareholdingDate, txtstockCode, lang):
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36', 'Content-Type': 'application/x-www-form-urlencoded'}
        if lang == 'c':
            url_address = 'https://www3.hkexnews.hk/sdw/search/searchsdw_c.aspx'
        else:
            url_address = 'https://www3.hkexnews.hk/sdw/search/searchsdw.aspx'
        data = '__EVENTTARGET=btnSearch&__EVENTARGUMENT=&today=' + today + '&sortBy=shareholding&sortDirection=desc&alertMsg=&txtShareholdingDate=' + txtShareholdingDate + '&txtStockCode=' + txtStockCode + '&txtStockName=&txtParticipantID=&txtParticipantName=&txtSelPartID='
        url = requests.request('POST',url_address, data=data, headers=headers)
        source = BeautifulSoup(url.text, 'html.parser')
        res = source.find_all('tbody')
        data = []
        for row in res[0]("tr"):
            items = {}
            items["id"] = row.find('td',attrs={'class','col-participant-id'}).find('div',attrs={'class','mobile-list-body'}).text.strip()
            items["name"] = row.find('td',attrs={'class','col-participant-name'}).find('div',attrs={'class','mobile-list-body'}).text.strip()
            items["shareholding"] = row.find('td',attrs={'class','col-shareholding'}).find('div',attrs={'class','mobile-list-body'}).text.strip()
            items["shareholding-percent"] = row.find('td',attrs={'class','col-shareholding-percent'}).find('div',attrs={'class','mobile-list-body'}).text.strip()
            items["matched"] = 'N'
            data.append(items)
        return data
    except:
        print("HKEX server issue. Please try again later")
        raise ValueError("HKEX server issue. Please try again later")

class Args: 
    def __init__(self): 
        self._code = ''
        self._start = ''
        self._end = ''
        self._lang = ''
        self._sort = ''

    def get_code(self): 
        return self._code 

    def set_code(self, a): 
        self._code = a 

    code = property(get_code, set_code) 

    def get_start(self): 
        return self._start 

    def set_start(self, a): 
        self._start = a 

    start = property(get_start, set_start) 

    def get_end(self): 
        return self._end 

    def set_end(self, a): 
        self._end = a 

    end = property(get_end, set_end) 

    def get_lang(self): 
        return self._lang 

    def set_lang(self, a): 
        self._lang = a 

    lang = property(get_lang, set_lang) 

    def get_sort(self): 
        return self._sort 

    def set_sort(self, a): 
        self._sort = a 

    sort = property(get_sort, set_sort)

if __name__ == "__main__":

    try:

        # Prepare the args
        args = Args()
        args.code = input("Stock Code (example: 1): ")
        validate_arg_code(args.code)
        args.start = input("Shareholding Start Date (example: 2024/12/30): ")
        validate_arg_start(args.start)
        args.end = input("Shareholding End Date (example: 2024/12/31): ")
        validate_arg_end(args.end)
        args.lang = input("Display Language [e: English, c: Chinese]: ").strip() or "c"
        args.sort = input("Sort by value [id: Participant Id, name: Participant Name, start: Shareholding Start, end: Shareholding End, change: Shareholding Change, change-percent: Shareholding Change Percent]: ").strip() or "change"

        txtStockCode = "{:05d}".format(int(args.code))
        txtShareholdingDateStart = urllib.parse.quote(args.start, safe='')
        txtShareholdingDateEnd = urllib.parse.quote(args.end, safe='')
        today = format(datetime.utcnow() + timedelta(hours=8), '%Y%m%d')

        # Call HTTP request to get data from HKEX
        json_start = searchsdw(today, txtShareholdingDateStart, txtStockCode, args.lang)
        json_end = searchsdw(today, txtShareholdingDateEnd, txtStockCode, args.lang)
        
        # Megre JSONs
        data = []
        table = []
        index = []
        for entry_json_start in json_start:
            for entry_json_end in json_end:
                if entry_json_start["id"] == entry_json_end["id"] and entry_json_start["name"] == entry_json_end["name"]:
                    entry_json_start["matched"] = 'Y'
                    entry_json_end["matched"] = 'Y'
                    shareholding_start = int(entry_json_start["shareholding"].replace(',',''))
                    shareholding_end = int(entry_json_end["shareholding"].replace(',',''))
                    shareholding_change = shareholding_end - shareholding_start
                    shareholding_change_percent = shareholding_change / shareholding_start * 100
                    items = {}
                    items["id"] = entry_json_start["id"] 
                    items["name"] = entry_json_start["name"]
                    items["start"] = shareholding_start
                    items["start-display"] = entry_json_start["shareholding"] + ' (' + entry_json_start["shareholding-percent"] + ')'
                    items["end"] = shareholding_end
                    items["end-display"] = entry_json_end["shareholding"] + ' (' + entry_json_end["shareholding-percent"] + ')'
                    items["change"] = shareholding_change
                    items["change-percent"] = shareholding_change_percent
                    items["change-display"] = f"{shareholding_change:,}" + ' (' + f'{round(shareholding_change_percent,2):.2f}' + '%)'
                    data.append(items)
        for entry_json_start in json_start:
            if entry_json_start["matched"] == 'N':
                shareholding_start = int(entry_json_start["shareholding"].replace(',',''))
                shareholding_end = 0
                shareholding_change = shareholding_end - shareholding_start
                shareholding_change_percent = -100
                items = {}
                items["id"] = entry_json_start["id"] 
                items["name"] = entry_json_start["name"]
                items["start"] = shareholding_start
                items["start-display"] = entry_json_start["shareholding"] + ' (' + entry_json_start["shareholding-percent"] + ')'
                items["end"] = shareholding_end
                items["end-display"] = '0 (0.00%)'
                items["change"] = shareholding_change
                items["change-percent"] = shareholding_change_percent
                items["change-display"] = f"{shareholding_change:,}" + ' (-100.00%)'
                data.append(items)
        for entry_json_end in json_end:
            if entry_json_end["matched"] == 'N':
                shareholding_start = 0
                shareholding_end = int(entry_json_end["shareholding"].replace(',',''))
                shareholding_change = shareholding_end - shareholding_start
                shareholding_change_percent = 100
                items = {}
                items["id"] = entry_json_end["id"] 
                items["name"] = entry_json_end["name"] 
                items["start"] = shareholding_start
                items["start-display"] = '0 (0.00%)'
                items["end"] = shareholding_end
                items["end-display"] = entry_json_end["shareholding"] + ' (' + entry_json_end["shareholding-percent"] + ')'
                items["change"] = shareholding_change
                items["change-percent"] = shareholding_change_percent
                items["change-display"] = f"{shareholding_change:,}" + ' (100.00%)'
                data.append(items)

        # Sort result JSON
        data.sort(key=lambda k: k[args.sort], reverse=True)

        # Prepare display table
        for json_data_sort_item in data:
            table.append([json_data_sort_item["start-display"],json_data_sort_item["end-display"],json_data_sort_item["change-display"]])
            index.append(json_data_sort_item["id"] + ' - ' + json_data_sort_item["name"] if len(json_data_sort_item["id"]) > 0 else json_data_sort_item["name"])

        pd.set_option('display.max_rows', None)
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 2000)
        pd.set_option('display.max_colwidth', None)
        pd.set_option("display.unicode.east_asian_width", True)
        
        if args.lang == 'c' :
            df = pd.DataFrame(table, columns = [args.start, args.end, '持股量 (%)'], index=index)
        else:
            df = pd.DataFrame(table, columns = [args.start, args.end, 'Shareholding (%)'], index=index)
        
        print(df)

        pd.reset_option('display.max_rows')
        pd.reset_option('display.max_columns')
        pd.reset_option('display.width')
        pd.reset_option('display.max_colwidth')

    except ValueError as error:

        print("An exception occurred:", error)
# Out:
#                                                                2023/10/01              2024/01/15              持股量 (%)
# A00003 - 中國証券登記結算有限責任公司               4,657,938,641 (9.79%)  5,163,823,188 (10.85%)    505,884,547 (10.86%)
# B01161 - UBS SECURITIES HONG KONG LTD                 881,242,045 (1.85%)   1,006,324,770 (2.11%)    125,082,725 (14.19%)
# C00093 - 法國巴黎銀行                                 204,989,633 (0.43%)     270,092,391 (0.56%)     65,102,758 (31.76%)
# B01228 - 中信証券經紀(香港)有限公司                    13,151,000 (0.02%)      42,966,000 (0.09%)    29,815,000 (226.71%)
# C00111 - Societe Generale                              20,913,311 (0.04%)      38,856,704 (0.08%)     17,943,393 (85.80%)
# B01138 - 中信里昂證券有限公司                             593,000 (0.00%)       9,173,000 (0.01%)    8,580,000 (1446.88%)
# C00036 - 中國建設銀行(亞洲)股份有限公司                16,731,547 (0.03%)      25,168,547 (0.05%)      8,437,000 (50.43%)
# B01955 - 富途證券國際(香港)有限公司                    39,277,124 (0.08%)      47,666,228 (0.10%)      8,389,104 (21.36%)
# B01727 - 工銀亞洲証券有限公司                          36,478,657 (0.07%)      43,256,109 (0.09%)      6,777,452 (18.58%)
# C00011 - 大眾銀行(香港)有限公司                            62,136 (0.00%)       5,432,136 (0.01%)    5,370,000 (8642.33%)
# C00088 - 招商銀行股份有限公司                          53,929,000 (0.11%)      58,811,000 (0.12%)       4,882,000 (9.05%)
# B01565 - 國泰君安證券(香港)有限公司                    36,282,792 (0.07%)      40,917,792 (0.08%)      4,635,000 (12.77%)
# B01654 - 中國國際金融香港證券有限公司                  25,503,504 (0.05%)      28,423,004 (0.05%)      2,919,500 (11.45%)
# B01610 - 凱基證券亞洲有限公司                          17,461,265 (0.03%)      18,795,265 (0.03%)       1,334,000 (7.64%)
# C00037 - 上海商業銀行有限公司                          23,237,967 (0.04%)      24,254,967 (0.05%)       1,017,000 (4.38%)
# B01842 - 交銀國際證券有限公司                          13,974,020 (0.02%)      14,729,020 (0.03%)         755,000 (5.40%)
# B01929 - 中國銀河國際證券(香港)有限公司                 1,074,083 (0.00%)       1,803,683 (0.00%)        729,600 (67.93%)
# B01885 - 哈富證券有限公司                               3,569,000 (0.00%)       4,200,000 (0.00%)        631,000 (17.68%)
# B01938 - 興證國際證券有限公司                          11,883,000 (0.02%)      12,361,000 (0.02%)         478,000 (4.02%)
# B02183 - 浦銀國際證券有限公司                              20,000 (0.00%)         489,000 (0.00%)      469,000 (2345.00%)
# B01623 - 大豐崑泰證券有限公司                           6,531,000 (0.01%)       6,979,000 (0.01%)         448,000 (6.86%)
# C00003 - 東亞銀行有限公司                              23,652,674 (0.04%)      24,075,915 (0.05%)         423,241 (1.79%)
# B01505 - 上銀證券有限公司                                 500,000 (0.00%)         900,000 (0.00%)        400,000 (80.00%)
# B01089 - 匯豐金融證券(香港)有限公司                    29,818,340 (0.06%)      30,199,340 (0.06%)         381,000 (1.28%)
# B01941 - 中原證券有限公司                                 132,117 (0.00%)         485,430 (0.00%)       353,313 (267.42%)
# B01901 - 招銀國際證券有限公司                          24,028,000 (0.05%)      24,370,000 (0.05%)         342,000 (1.42%)
# C00026 - 創興銀行有限公司                                 587,000 (0.00%)         907,000 (0.00%)        320,000 (54.51%)
# B01624 - 中衛投資有限公司                              12,150,000 (0.02%)      12,424,000 (0.02%)         274,000 (2.26%)
# B02038 - 西牛證券有限公司                                       0 (0.00%)         270,000 (0.00%)       270,000 (100.00%)
# B01459 - 奕豐證券(香港)有限公司                         1,101,800 (0.00%)       1,337,800 (0.00%)        236,000 (21.42%)
# B01980 - 山證國際證券有限公司                               2,000 (0.00%)         235,000 (0.00%)     233,000 (11650.00%)
# B02159 - 盈立證券有限公司                                 384,243 (0.00%)         609,568 (0.00%)        225,325 (58.64%)
# B01832 - 瑞穗證券亞洲有限公司                               8,000 (0.00%)         231,000 (0.00%)      223,000 (2787.50%)
# B01338 - 英皇證券有限公司                               1,723,250 (0.00%)       1,940,250 (0.00%)        217,000 (12.59%)
# B01848 - 國泰證券(香港)有限公司                           763,000 (0.00%)         974,000 (0.00%)        211,000 (27.65%)
# B01224 - MLFE LTD                                      29,099,504 (0.06%)      29,308,382 (0.06%)         208,878 (0.72%)
# B01673 - 富昌證券有限公司                               1,156,431 (0.00%)       1,345,431 (0.00%)        189,000 (16.34%)
# B01937 - 長江證券經紀(香港)有限公司                       336,000 (0.00%)         501,000 (0.00%)        165,000 (49.11%)
# B02091 - 瑞豐證券有限公司                                  10,000 (0.00%)         165,000 (0.00%)      155,000 (1550.00%)
# B01298 - 結好證券有限公司                                 620,000 (0.00%)         772,000 (0.00%)        152,000 (24.52%)
# B01550 - 華裕證券有限公司                                       0 (0.00%)         120,000 (0.00%)       120,000 (100.00%)
# B01875 - 國都證券(香港)有限公司                           271,000 (0.00%)         388,000 (0.00%)        117,000 (43.17%)
# B01695 - 大新證券有限公司                              21,948,458 (0.04%)      22,055,994 (0.04%)         107,536 (0.49%)
# C00028 - 南洋商業銀行有限公司                          18,195,712 (0.03%)      18,303,151 (0.03%)         107,439 (0.59%)
# B02176 - 平證證券(香港)有限公司                         1,040,000 (0.00%)       1,145,000 (0.00%)        105,000 (10.10%)
# B01665 - 永勝證券有限公司                                  56,000 (0.00%)         156,000 (0.00%)       100,000 (178.57%)
# B01567 - 發利證券有限公司                                 201,000 (0.00%)         281,000 (0.00%)         80,000 (39.80%)
# B01439 - 大德證券(亞洲)有限公司                           285,000 (0.00%)         361,000 (0.00%)         76,000 (26.67%)
# B01588 - 利星行證券有限公司                               119,500 (0.00%)         184,500 (0.00%)         65,000 (54.39%)
# B01551 - 越秀証券有限公司                                  79,000 (0.00%)         143,000 (0.00%)         64,000 (81.01%)
# B01849 - 順安證券資產管理有限公司                         407,000 (0.00%)         467,000 (0.00%)         60,000 (14.74%)
# B02163 - 金鷹證券有限公司                                       0 (0.00%)          59,000 (0.00%)        59,000 (100.00%)
# B01510 - 東英亞洲證券有限公司                              21,000 (0.00%)          79,000 (0.00%)        58,000 (276.19%)
# B01963 - 天風國際證券與期貨有限公司                       178,000 (0.00%)         235,000 (0.00%)         57,000 (32.02%)
# B01677 - 鉅亨證券有限公司                                 112,000 (0.00%)         153,000 (0.00%)         41,000 (36.61%)
# B01940 - SOFI SECURITIES (HONG KONG) LTD                  419,500 (0.00%)         453,500 (0.00%)          34,000 (8.10%)
# B01581 - 滙富金融服務有限公司                           5,420,000 (0.01%)       5,453,000 (0.01%)          33,000 (0.61%)
# B02184 - 鼎鑫(證券)有限公司                                     0 (0.00%)          33,000 (0.00%)        33,000 (100.00%)
# B02210 - 諾亞控股(香港)有限公司                                 0 (0.00%)          33,000 (0.00%)        33,000 (100.00%)
# B01900 - 東方證券(香港)有限公司                           745,000 (0.00%)         777,000 (0.00%)          32,000 (4.30%)
# B01158 - 堅固證券有限公司                                 557,000 (0.00%)         588,000 (0.00%)          31,000 (5.57%)
# B01407 - 宏旺證券有限公司                                 262,000 (0.00%)         292,000 (0.00%)         30,000 (11.45%)
# B01995 - 加多利證券有限公司                                     0 (0.00%)          30,000 (0.00%)        30,000 (100.00%)
# B01552 - 嘉利證券投資有限公司                             464,000 (0.00%)         493,000 (0.00%)          29,000 (6.25%)
# B02021 - 新嘉財富證券有限公司                              10,000 (0.00%)          39,000 (0.00%)        29,000 (290.00%)
# B01601 - 群益證券(香港)有限公司                           177,000 (0.00%)         205,000 (0.00%)         28,000 (15.82%)
# B01947 - 富邦證券(香港)有限公司                         1,019,000 (0.00%)       1,046,000 (0.00%)          27,000 (2.65%)
# B01129 - 宏高證券有限公司                                 516,000 (0.00%)         543,000 (0.00%)          27,000 (5.23%)
# B01967 - 雲鋒證券有限公司                                 141,000 (0.00%)         168,000 (0.00%)         27,000 (19.15%)
# B02142 - 老虎證券(香港)環球有限公司                     2,492,481 (0.00%)       2,515,865 (0.00%)          23,384 (0.94%)
# B02151 - 善恆證券有限公司                                       0 (0.00%)          23,000 (0.00%)        23,000 (100.00%)
# B01438 - 金利豐證券有限公司                               370,000 (0.00%)         392,000 (0.00%)          22,000 (5.95%)
# B01173 - 日發證券有限公司                                 202,000 (0.00%)         224,000 (0.00%)         22,000 (10.89%)
# B01669 - 第一證券(香港)有限公司                           243,000 (0.00%)         263,000 (0.00%)          20,000 (8.23%)
# B01788 - 齊榮證券有限公司                                 129,000 (0.00%)         149,000 (0.00%)         20,000 (15.50%)
# B01322 - 華通證券國際有限公司                              10,000 (0.00%)          30,000 (0.00%)        20,000 (200.00%)
# B01481 - 恆盛證券有限公司                                  75,000 (0.00%)          94,055 (0.00%)         19,055 (25.41%)
# B02032 - 方德證券有限公司                                  61,000 (0.00%)          80,000 (0.00%)         19,000 (31.15%)
# B01930 - 安裕證券投資有限公司                               3,000 (0.00%)          21,000 (0.00%)        18,000 (600.00%)
# B01347 - 銀河—聯昌證券(香港)有限公司                    6,993,300 (0.01%)       7,010,300 (0.01%)          17,000 (0.24%)
# B02181 - 大唐資本證券有限公司                             545,000 (0.00%)         559,000 (0.00%)          14,000 (2.57%)
# B02102 - 尊嘉證券國際有限公司                             315,000 (0.00%)         329,000 (0.00%)          14,000 (4.44%)
# B01753 - 富強證券有限公司                                  30,000 (0.00%)          41,000 (0.00%)         11,000 (36.67%)
# B01340 - 利興股票有限公司                                 232,108 (0.00%)         242,108 (0.00%)          10,000 (4.31%)
# B01759 - 永聯財富管理有限公司                             117,000 (0.00%)         127,000 (0.00%)          10,000 (8.55%)
# B01982 - 中州國際證券有限公司                              82,000 (0.00%)          92,000 (0.00%)         10,000 (12.20%)
# B01509 - 益群證券有限公司                                  45,000 (0.00%)          55,000 (0.00%)         10,000 (22.22%)
# B01470 - 鴻昇證券有限公司                                 134,000 (0.00%)         143,000 (0.00%)           9,000 (6.72%)
# B01324 - FUNDERSTONE SECURITIES LTD                       126,000 (0.00%)         135,000 (0.00%)           9,000 (7.14%)
# B01271 - 恒泰証券有限公司                                 152,000 (0.00%)         160,000 (0.00%)           8,000 (5.26%)
# B01386 - 軟庫中華金融服務有限公司                         704,000 (0.00%)         711,000 (0.00%)           7,000 (0.99%)
# B01814 - 立橋證券有限公司                                 382,000 (0.00%)         389,000 (0.00%)           7,000 (1.83%)
# B01782 - 恒昇證券有限公司                                 109,000 (0.00%)         116,000 (0.00%)           7,000 (6.42%)
# B01535 - 詠誼證券投資有限公司                             177,000 (0.00%)         182,000 (0.00%)           5,000 (2.82%)
# B01320 - 聯發證券有限公司                                  83,000 (0.00%)          88,000 (0.00%)           5,000 (6.02%)
# B02162 - 嘉謨證券有限公司                                   3,000 (0.00%)           8,000 (0.00%)         5,000 (166.67%)
# B02093 - 晉億證券有限公司                                  37,615 (0.00%)          42,397 (0.00%)          4,782 (12.71%)
# B01209 - 茂宸證券有限公司                                 639,000 (0.00%)         643,000 (0.00%)           4,000 (0.63%)
# B01415 - 泰山證券有限公司                                 125,000 (0.00%)         129,000 (0.00%)           4,000 (3.20%)
# B01181 - 復星國際證券有限公司                              74,000 (0.00%)          78,000 (0.00%)           4,000 (5.41%)
# B02213 - 中信信期國際證券有限公司                               0 (0.00%)           4,000 (0.00%)         4,000 (100.00%)
# B02030 - 中富證券有限公司                                  30,000 (0.00%)          33,000 (0.00%)          3,000 (10.00%)
# B01789 - 浩豐證券投資有限公司                              12,000 (0.00%)          14,500 (0.00%)          2,500 (20.83%)
# B02195 - 長橋證券(香港)有限公司                         2,386,201 (0.00%)       2,388,471 (0.00%)           2,270 (0.10%)
# B01119 - 時富證券有限公司                                 753,000 (0.00%)         755,000 (0.00%)           2,000 (0.27%)
# B01433 - 興偉聯合證券有限公司                             139,000 (0.00%)         141,000 (0.00%)           2,000 (1.44%)
# B01454 - 昊天國際證券有限公司                             128,000 (0.00%)         130,000 (0.00%)           2,000 (1.56%)
# B02047 - 艾德證券期貨有限公司                              76,000 (0.00%)          78,000 (0.00%)           2,000 (2.63%)
# B02128 - 元庫證券有限公司                                  54,000 (0.00%)          56,000 (0.00%)           2,000 (3.70%)
# B01724 - 偉文証券有限公司                                  34,000 (0.00%)          36,000 (0.00%)           2,000 (5.88%)
# B01633 - 名匯證券有限公司                                  28,000 (0.00%)          30,000 (0.00%)           2,000 (7.14%)
# B02019 - 智易東方證券有限公司                              27,000 (0.00%)          29,000 (0.00%)           2,000 (7.41%)
# B01267 - 永富證券有限公司                                 339,000 (0.00%)         340,000 (0.00%)           1,000 (0.29%)
# B01809 - 華信證券有限公司                                 121,000 (0.00%)         122,000 (0.00%)           1,000 (0.83%)
# B01754 - 華億證券有限公司                                  13,000 (0.00%)          14,000 (0.00%)           1,000 (7.69%)
# B01240 - 秦志遠證券有限公司                               128,494 (0.00%)         128,965 (0.00%)             471 (0.37%)
# B01823 - 英高證券有限公司                               1,093,000 (0.00%)       1,093,000 (0.00%)               0 (0.00%)
# B02185 - 韓國投資證券亞洲有限公司                         814,680 (0.00%)         814,680 (0.00%)               0 (0.00%)
# B01543 - 廣發行証券有限公司                               701,000 (0.00%)         701,000 (0.00%)               0 (0.00%)
# B01645 - 永高證券有限公司                                 412,000 (0.00%)         412,000 (0.00%)               0 (0.00%)
# B01893 - 匯濤證券有限公司                                 403,000 (0.00%)         403,000 (0.00%)               0 (0.00%)
# B02203 - 意博資本亞洲有限公司                             360,000 (0.00%)         360,000 (0.00%)               0 (0.00%)
# B01576 - 兆安證券有限公司                                 322,000 (0.00%)         322,000 (0.00%)               0 (0.00%)
# B01450 - 佐雄證券有限公司                                 295,000 (0.00%)         295,000 (0.00%)               0 (0.00%)
# B01252 - 協聯證券有限公司                                 285,000 (0.00%)         285,000 (0.00%)               0 (0.00%)
# B01592 - 百德能經紀有限公司                               258,000 (0.00%)         258,000 (0.00%)               0 (0.00%)
# B01123 - 興旺證券有限公司                                 245,000 (0.00%)         245,000 (0.00%)               0 (0.00%)
# B01511 - 達利證券有限公司                                 184,000 (0.00%)         184,000 (0.00%)               0 (0.00%)
# B01350 - 榮興證券有限公司                                 164,000 (0.00%)         164,000 (0.00%)               0 (0.00%)
# B01157 - 巴西證券有限公司                                 150,000 (0.00%)         150,000 (0.00%)               0 (0.00%)
# B01575 - 恒富證券有限公司                                 142,000 (0.00%)         142,000 (0.00%)               0 (0.00%)
# B01080 - 鼎珮證券有限公司                                 141,000 (0.00%)         141,000 (0.00%)               0 (0.00%)
# B01230 - 太平基業證券有限公司                             129,000 (0.00%)         129,000 (0.00%)               0 (0.00%)
# B02026 - 昇悅證券有限公司                                 123,000 (0.00%)         123,000 (0.00%)               0 (0.00%)
# B01958 - 瑭明金融集團有限公司                             110,000 (0.00%)         110,000 (0.00%)               0 (0.00%)
# B01351 - 永豐證券有限公司                                 104,500 (0.00%)         104,500 (0.00%)               0 (0.00%)
# B01784 - 富業證券投資有限公司                             101,000 (0.00%)         101,000 (0.00%)               0 (0.00%)
# B01925 - 邦盟滙駿證券有限公司                              93,000 (0.00%)          93,000 (0.00%)               0 (0.00%)
# B01294 - 中策富匯證券有限公司                              89,000 (0.00%)          89,000 (0.00%)               0 (0.00%)
# B01787 - 蘇佩瓚證券有限公司                                86,000 (0.00%)          86,000 (0.00%)               0 (0.00%)
# B01246 - 鷹達證券有限公司                                  73,000 (0.00%)          73,000 (0.00%)               0 (0.00%)
# B01685 - 恆大證券(香港)有限公司                            73,000 (0.00%)          73,000 (0.00%)               0 (0.00%)
# B01993 - 高誠證券有限公司                                  73,000 (0.00%)          73,000 (0.00%)               0 (0.00%)
# B01525 - 祺昌證券有限公司                                  72,000 (0.00%)          72,000 (0.00%)               0 (0.00%)
# B01936 - 敏哲証券有限公司                                  68,000 (0.00%)          68,000 (0.00%)               0 (0.00%)
# B01646 - 大寧證券有限公司                                  63,000 (0.00%)          63,000 (0.00%)               0 (0.00%)
# B01213 - 萬利豐證券有限公司                                58,000 (0.00%)          58,000 (0.00%)               0 (0.00%)
# B01458 - 益高證券有限公司                                  54,000 (0.00%)          54,000 (0.00%)               0 (0.00%)
# B01577 - 怡發證券有限公司                                  50,000 (0.00%)          50,000 (0.00%)               0 (0.00%)
# B01748 - 聯勝網上證券有限公司                              50,000 (0.00%)          50,000 (0.00%)               0 (0.00%)
# B01990 - 冠力金融服務有限公司                              50,000 (0.00%)          50,000 (0.00%)               0 (0.00%)
# B01810 - 阿仕特朗資本管理有限公司                          40,000 (0.00%)          40,000 (0.00%)               0 (0.00%)
# B01974 - 雅利多證券有限公司                                40,000 (0.00%)          40,000 (0.00%)               0 (0.00%)
# B02085 - 海富證券投資有限公司                              40,000 (0.00%)          40,000 (0.00%)               0 (0.00%)
# B01891 - 聚合金融服務有限公司                              38,000 (0.00%)          38,000 (0.00%)               0 (0.00%)
# B01310 - 同德証券(香港)有限公司                            36,000 (0.00%)          36,000 (0.00%)               0 (0.00%)
# B01659 - 滿好證券有限公司                                  36,000 (0.00%)          36,000 (0.00%)               0 (0.00%)
# LEE KING FAI *                                             30,000 (0.00%)          30,000 (0.00%)               0 (0.00%)
# B01192 - 中南金融有限公司                                  30,000 (0.00%)          30,000 (0.00%)               0 (0.00%)
# B02042 - 大聖證券有限公司                                  30,000 (0.00%)          30,000 (0.00%)               0 (0.00%)
# B02035 - 華大證券有限公司                                  25,000 (0.00%)          25,000 (0.00%)               0 (0.00%)
# B01706 - 文漢揚証券有限公司                                24,000 (0.00%)          24,000 (0.00%)               0 (0.00%)
# B01231 - 香港國際證券有限公司                              23,000 (0.00%)          23,000 (0.00%)               0 (0.00%)
# HARMONY ENTERPRISES LIMITED *                              20,000 (0.00%)          20,000 (0.00%)               0 (0.00%)
# B01964 - 鎧盛證券有限公司                                  20,000 (0.00%)          20,000 (0.00%)               0 (0.00%)
# B01756 - 中天證券有限公司                                  18,000 (0.00%)          18,000 (0.00%)               0 (0.00%)
# B01680 - 實德證券有限公司                                  17,000 (0.00%)          17,000 (0.00%)               0 (0.00%)
# B01767 - 新基立證券有限公司                                17,000 (0.00%)          17,000 (0.00%)               0 (0.00%)
# B01248 - 均益證券(國際)有限公司                            15,000 (0.00%)          15,000 (0.00%)               0 (0.00%)
# B01868 - 集美證券有限公司                                  15,000 (0.00%)          15,000 (0.00%)               0 (0.00%)
# B01694 - 嬴控金融證券有限公司                              14,000 (0.00%)          14,000 (0.00%)               0 (0.00%)
# B01751 - IMAGI BROKERAGE LTD                               13,000 (0.00%)          13,000 (0.00%)               0 (0.00%)
# B01833 - 中國信託綜合證券(香港)有限公司                    12,000 (0.00%)          12,000 (0.00%)               0 (0.00%)
# B02112 - 凱匯資本證券有限公司                              12,000 (0.00%)          12,000 (0.00%)               0 (0.00%)
# B01660 - 國投證券有限公司                                  11,000 (0.00%)          11,000 (0.00%)               0 (0.00%)
# B02108 - 勁域證券有限公司                                  11,000 (0.00%)          11,000 (0.00%)               0 (0.00%)
# LAI CHIU WING *                                            10,000 (0.00%)          10,000 (0.00%)               0 (0.00%)
# B01326 - 摩根富國證券有限公司                              10,000 (0.00%)          10,000 (0.00%)               0 (0.00%)
# B02133 - 中國證券有限公司                                  10,000 (0.00%)          10,000 (0.00%)               0 (0.00%)
# B02138 - 駿達證券有限公司                                  10,000 (0.00%)          10,000 (0.00%)               0 (0.00%)
# B01697 - 晉商證券有限公司                                   9,000 (0.00%)           9,000 (0.00%)               0 (0.00%)
# YU MAN TING *                                               8,000 (0.00%)           8,000 (0.00%)               0 (0.00%)
# B01308 - 渼豐資產管理有限公司                               8,000 (0.00%)           8,000 (0.00%)               0 (0.00%)
# B01604 - 華邦證券有限公司                                   7,000 (0.00%)           7,000 (0.00%)               0 (0.00%)
# B01806 - 中華匯財金融有限公司                               7,000 (0.00%)           7,000 (0.00%)               0 (0.00%)
# B01447 - 華德國際證券有限公司                               5,000 (0.00%)           5,000 (0.00%)               0 (0.00%)
# B01493 - 溢利證券有限公司                                   5,000 (0.00%)           5,000 (0.00%)               0 (0.00%)
# B01508 - 西證(香港)證券經紀有限公司                         5,000 (0.00%)           5,000 (0.00%)               0 (0.00%)
# B01794 - 通陸證券有限公司                                   5,000 (0.00%)           5,000 (0.00%)               0 (0.00%)
# B02017 - 匯生證券有限公司                                   5,000 (0.00%)           5,000 (0.00%)               0 (0.00%)
# B02096 - 高鉦証券有限公司                                   5,000 (0.00%)           5,000 (0.00%)               0 (0.00%)
# B01318 - 岡三國際(亞洲)有限公司                             4,000 (0.00%)           4,000 (0.00%)               0 (0.00%)
# B01410 - 金鵬證券有限公司                                   4,000 (0.00%)           4,000 (0.00%)               0 (0.00%)
# B01883 - 華晉證券資產管理有限公司                           4,000 (0.00%)           4,000 (0.00%)               0 (0.00%)
# B02092 - 一盈證券有限公司                                   4,000 (0.00%)           4,000 (0.00%)               0 (0.00%)
# B02180 - 貝德斯證券有限公司                                 4,000 (0.00%)           4,000 (0.00%)               0 (0.00%)
# B01277 - 源盛證券有限公司                                   3,000 (0.00%)           3,000 (0.00%)               0 (0.00%)
# B01907 - 國農證券有限公司                                   3,000 (0.00%)           3,000 (0.00%)               0 (0.00%)
# B02157 - 恩明資產証券有限公司                               3,000 (0.00%)           3,000 (0.00%)               0 (0.00%)
# SEEN SIU LAM *                                              2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# YIP MING SHUM *                                             2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01341 - 東泰證券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01547 - 國興証券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01609 - 惠興証券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01627 - 山高國際證券有限公司                               2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01632 - 威發證券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01679 - 大豐證券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01745 - 漢華證券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01918 - 偉祿亞太證券有限公司                               2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01922 - 太陽證券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01972 - 聚富證券有限公司                                   2,000 (0.00%)           2,000 (0.00%)               0 (0.00%)
# B01795 - RAFFAELLO SECURITIES (HK) LTD                      1,000 (0.00%)           1,000 (0.00%)               0 (0.00%)
# B02003 - 東興證券(香港)有限公司                             1,000 (0.00%)           1,000 (0.00%)               0 (0.00%)
# B02041 - 信銀(香港)資本有限公司                             1,000 (0.00%)           1,000 (0.00%)               0 (0.00%)
# B02075 - 創陞證券有限公司                                   1,000 (0.00%)           1,000 (0.00%)               0 (0.00%)
# B01755 - 匯澤證券有限公司                                     965 (0.00%)             965 (0.00%)               0 (0.00%)
# B01813 - 建銀國際證券有限公司                           6,228,400 (0.01%)       6,227,400 (0.01%)         -1,000 (-0.02%)
# B01421 - 環一證券有限公司                                 542,000 (0.00%)         541,000 (0.00%)         -1,000 (-0.18%)
# B01328 - 萬興證券有限公司                                 314,000 (0.00%)         313,000 (0.00%)         -1,000 (-0.32%)
# B01275 - 新富證券有限公司                                 286,000 (0.00%)         285,000 (0.00%)         -1,000 (-0.35%)
# B01684 - 永安證券有限公司                                  51,000 (0.00%)          50,000 (0.00%)         -1,000 (-1.96%)
# B01976 - 方達資本管理有限公司                              10,000 (0.00%)           9,000 (0.00%)        -1,000 (-10.00%)
# B01981 - 青石證券(香港)有限公司                             2,000 (0.00%)           1,000 (0.00%)        -1,000 (-50.00%)
# B01466 - 矩陣證券有限公司                                   1,000 (0.00%)               0 (0.00%)       -1,000 (-100.00%)
# B01986 - 華金證券(國際)有限公司                             1,000 (0.00%)               0 (0.00%)       -1,000 (-100.00%)
# B01259 - 天發證券有限公司                                 327,000 (0.00%)         325,000 (0.00%)         -2,000 (-0.61%)
# B01483 - 利銘證券有限公司                                 237,000 (0.00%)         235,000 (0.00%)         -2,000 (-0.84%)
# B01915 - 元宇證券有限公司                                  68,000 (0.00%)          66,000 (0.00%)         -2,000 (-2.94%)
# B01765 - 昌盛證券有限公司                                  57,000 (0.00%)          55,000 (0.00%)         -2,000 (-3.51%)
# B01712 - 華生證券有限公司                                  39,000 (0.00%)          37,000 (0.00%)         -2,000 (-5.13%)
# B01802 - 泓福證券有限公司                                  12,000 (0.00%)          10,000 (0.00%)        -2,000 (-16.67%)
# B01290 - 新寶城證券有限公司                                 7,000 (0.00%)           5,000 (0.00%)        -2,000 (-28.57%)
# B01863 - 微投證券國際(香港)有限公司                         2,274 (0.00%)             274 (0.00%)        -2,000 (-87.95%)
# B01385 - 海富證券有限公司                                   2,000 (0.00%)               0 (0.00%)       -2,000 (-100.00%)
# B02140 - 金信期盈證券(香港)有限公司                         2,000 (0.00%)               0 (0.00%)       -2,000 (-100.00%)
# B01606 - 穎翔證券有限公司                                   3,000 (0.00%)               0 (0.00%)       -3,000 (-100.00%)
# B01720 - 江陸證券有限公司                                   3,000 (0.00%)               0 (0.00%)       -3,000 (-100.00%)
# B01783 - 中發証券有限公司                                 497,000 (0.00%)         492,000 (0.00%)         -5,000 (-1.01%)
# B01564 - 農銀國際證券有限公司                             442,000 (0.00%)         437,000 (0.00%)         -5,000 (-1.13%)
# B01253 - 常匯證券有限公司                                  75,000 (0.00%)          70,000 (0.00%)         -5,000 (-6.67%)
# B01666 - 寶新證券有限公司                                  61,000 (0.00%)          56,000 (0.00%)         -5,000 (-8.20%)
# B01523 - 長雄證券有限公司                                  43,000 (0.00%)          38,000 (0.00%)        -5,000 (-11.63%)
# B01519 - 豐年証券投資有限公司                              12,000 (0.00%)           7,000 (0.00%)        -5,000 (-41.67%)
# B01374 - 寶利證券有限公司                                   7,000 (0.00%)           2,000 (0.00%)        -5,000 (-71.43%)
# B01500 - 申新證券有限公司                                   5,000 (0.00%)               0 (0.00%)       -5,000 (-100.00%)
# B01676 - 大盛証券投資有限公司                             664,000 (0.00%)         658,000 (0.00%)         -6,000 (-0.90%)
# B02175 - 微牛證券有限公司                                 228,000 (0.00%)         222,000 (0.00%)         -6,000 (-2.63%)
# B01427 - 謝氏膺暉證券有限公司                             277,000 (0.00%)         270,000 (0.00%)         -7,000 (-2.53%)
# B01700 - 滙信理財有限公司                                 250,000 (0.00%)         242,000 (0.00%)         -8,000 (-3.20%)
# B01265 - 華僑證券經紀 (香港) 有限公司                     348,000 (0.00%)         338,145 (0.00%)         -9,855 (-2.83%)
# B01636 - 東信證券有限公司                                  85,000 (0.00%)          75,000 (0.00%)       -10,000 (-11.76%)
# B02212 - 華安證券(香港)經紀有限公司                        50,000 (0.00%)          40,000 (0.00%)       -10,000 (-20.00%)
# B01428 - 協興股票有限公司                                  17,000 (0.00%)           7,000 (0.00%)       -10,000 (-58.82%)
# B01392 - 大輝證券有限公司                                  15,000 (0.00%)           5,000 (0.00%)       -10,000 (-66.67%)
# B01769 - 一中證券有限公司                                 145,657 (0.00%)         135,058 (0.00%)        -10,599 (-7.28%)
# B01141 - 廣利証券有限公司                                  37,000 (0.00%)          26,000 (0.00%)       -11,000 (-29.73%)
# B01585 - 華誠證券有限公司                                 236,000 (0.00%)         224,000 (0.00%)        -12,000 (-5.08%)
# B01546 - 和豐證券有限公司                                  89,000 (0.00%)          77,000 (0.00%)       -12,000 (-13.48%)
# B02106 - 弘業國際金融控股有限公司                          63,000 (0.00%)          51,000 (0.00%)       -12,000 (-19.05%)
# B02116 - 海盈證券有限公司                                  62,000 (0.00%)          50,000 (0.00%)       -12,000 (-19.35%)
# B01238 - 大業證券有限公司                                 252,000 (0.00%)         238,000 (0.00%)        -14,000 (-5.56%)
# B01425 - 偉富證券有限公司                                 342,000 (0.00%)         327,000 (0.00%)        -15,000 (-4.39%)
# B01444 - 粵興證券有限公司                                  75,891 (0.00%)          60,891 (0.00%)       -15,000 (-19.77%)
# B01716 - 東方匯財證券有限公司                             122,000 (0.00%)         103,000 (0.00%)       -19,000 (-15.57%)
# B01743 - 世博證券有限公司                                  42,000 (0.00%)          22,000 (0.00%)       -20,000 (-47.62%)
# B01851 - 富明證券有限公司                                  20,000 (0.00%)               0 (0.00%)      -20,000 (-100.00%)
# B02031 - 金聯證券有限公司                                  20,000 (0.00%)               0 (0.00%)      -20,000 (-100.00%)
# B01198 - 步基證券有限公司                                 249,500 (0.00%)         225,500 (0.00%)        -24,000 (-9.62%)
# B01292 - 亞華證券有限公司                                 176,000 (0.00%)         152,000 (0.00%)       -24,000 (-13.64%)
# B01563 - 華融國際證券有限公司                             161,000 (0.00%)         137,000 (0.00%)       -24,000 (-14.91%)
# B02020 - 富匯證券有限公司                                  24,000 (0.00%)               0 (0.00%)      -24,000 (-100.00%)
# B01971 - 橫華國際証券有限公司                             104,000 (0.00%)          78,000 (0.00%)       -26,000 (-25.00%)
# B01217 - 太平証券(香港)有限公司                           651,820 (0.00%)         624,820 (0.00%)        -27,000 (-4.14%)
# B01741 - 佳富達證券有限公司                                56,000 (0.00%)          29,000 (0.00%)       -27,000 (-48.21%)
# B01343 - 展兆投資有限公司                                 161,000 (0.00%)         133,000 (0.00%)       -28,000 (-17.39%)
# B01362 - JOSPA INVESTMENT CO LTD                           28,000 (0.00%)               0 (0.00%)      -28,000 (-100.00%)
# B01494 - 高陞證券有限公司                                 393,000 (0.00%)         363,000 (0.00%)        -30,000 (-7.63%)
# B01866 - 工銀國際證券有限公司                           6,795,000 (0.01%)       6,764,000 (0.01%)        -31,000 (-0.46%)
# B01773 - 東洋証券亞洲有限公司                           1,931,500 (0.00%)       1,899,500 (0.00%)        -32,000 (-1.66%)
# B01423 - 信誠證券有限公司                               2,317,000 (0.00%)       2,281,000 (0.00%)        -36,000 (-1.55%)
# B01779 - 李氏證券有限公司                                  87,000 (0.00%)          50,000 (0.00%)       -37,000 (-42.53%)
# B01731 - 信亨証券有限公司                                  37,000 (0.00%)               0 (0.00%)      -37,000 (-100.00%)
# B01615 - 金輝証券有限公司                                  86,000 (0.00%)          46,000 (0.00%)       -40,000 (-46.51%)
# B02100 - 永裕證券有限公司                                  70,000 (0.00%)          30,000 (0.00%)       -40,000 (-57.14%)
# B01528 - 東美證券有限公司                                  40,000 (0.00%)               0 (0.00%)      -40,000 (-100.00%)
# B01957 - 鼎石證券有限公司                                  40,000 (0.00%)               0 (0.00%)      -40,000 (-100.00%)
# B01661 - 凱敏證券有限公司                                 372,824 (0.00%)         327,824 (0.00%)       -45,000 (-12.07%)
# B01143 - 海通國際證券有限公司                           4,303,728 (0.00%)       4,257,028 (0.00%)        -46,700 (-1.09%)
# B01584 - 致富證券有限公司                               4,818,381 (0.01%)       4,770,325 (0.01%)        -48,056 (-1.00%)
# B01540 - 美建證券有限公司                                 192,000 (0.00%)         141,000 (0.00%)       -51,000 (-26.56%)
# B01169 - 大眾金融証券有限公司                           1,377,500 (0.00%)       1,322,500 (0.00%)        -55,000 (-3.99%)
# B01959 - 中泰國際證券有限公司                           6,656,000 (0.01%)       6,591,000 (0.01%)        -65,000 (-0.98%)
# B01777 - 大和資本市場香港有限公司                       2,177,000 (0.00%)       2,110,000 (0.00%)        -67,000 (-3.08%)
# B01894 - 峰匯金融集團有限公司                             329,000 (0.00%)         261,000 (0.00%)       -68,000 (-20.67%)
# B01710 - 中順證券期貨有限公司                             245,000 (0.00%)         169,000 (0.00%)       -76,000 (-31.02%)
# B01858 - 元大證券(香港)有限公司                         3,707,440 (0.00%)       3,630,440 (0.00%)        -77,000 (-2.08%)
# B02120 - 利弗莫爾證券有限公司                             151,000 (0.00%)          74,000 (0.00%)       -77,000 (-50.99%)
# B01497 - 永豐金證券(亞洲)有限公司                       3,557,000 (0.00%)       3,471,000 (0.00%)        -86,000 (-2.42%)
# B01256 - 國金證券(香港)有限公司                         1,050,000 (0.00%)         957,000 (0.00%)        -93,000 (-8.86%)
# B01651 - 明漢證券有限公司                                  93,000 (0.00%)               0 (0.00%)      -93,000 (-100.00%)
# B01705 - 恒億證券有限公司                                 235,000 (0.00%)         129,000 (0.00%)      -106,000 (-45.11%)
# B02177 - 浙商國際金融控股有限公司                         150,000 (0.00%)          39,000 (0.00%)      -111,000 (-74.00%)
# B01897 - 中達證券投資有限公司                             154,000 (0.00%)          31,000 (0.00%)      -123,000 (-79.87%)
# B01372 - 第一金和昇證券有限公司                           130,000 (0.00%)               0 (0.00%)     -130,000 (-100.00%)
# B01373 - 恆豐證券有限公司                                 488,000 (0.00%)         346,000 (0.00%)      -142,000 (-29.10%)
# C00048 - 集友銀行有限公司                               8,907,339 (0.01%)       8,763,991 (0.01%)       -143,348 (-1.61%)
# B01649 - 信達國際證券有限公司                           1,128,000 (0.00%)         980,000 (0.00%)      -148,000 (-13.12%)
# B01356 - 匯業證券有限公司                                 766,000 (0.00%)         596,000 (0.00%)      -170,000 (-22.19%)
# B01416 - 匯盈證券有限公司                                 336,000 (0.00%)         165,000 (0.00%)      -171,000 (-50.89%)
# B01696 - 亨達証券有限公司                                 200,000 (0.00%)          25,000 (0.00%)      -175,000 (-87.50%)
# B01973 - 寶鉅證券有限公司                                 704,000 (0.00%)         515,000 (0.00%)      -189,000 (-26.85%)
# B01445 - 勝利證券有限公司                                 363,000 (0.00%)         158,000 (0.00%)      -205,000 (-56.47%)
# B02125 - 中國銀盛國際有限公司                             231,000 (0.00%)           1,000 (0.00%)      -230,000 (-99.57%)
# B01843 - 電訊數碼證券有限公司                             531,000 (0.00%)         295,000 (0.00%)      -236,000 (-44.44%)
# B01556 - 六福證券(香港)有限公司                           882,000 (0.00%)         643,000 (0.00%)      -239,000 (-27.10%)
# B01829 - 華泰金融控股(香港)有限公司                    22,086,459 (0.04%)      21,839,168 (0.04%)       -247,291 (-1.12%)
# B01184 - 華富建業證券有限公司                             923,384 (0.00%)         660,384 (0.00%)      -263,000 (-28.48%)
# B01455 - 中潤證券有限公司                               1,949,000 (0.00%)       1,679,000 (0.00%)      -270,000 (-13.85%)
# B02132 - 寶盛證券(香港)有限公司                         3,189,096 (0.00%)       2,913,096 (0.00%)       -276,000 (-8.65%)
# B01289 - 南華證券投資有限公司                           1,159,000 (0.00%)         873,000 (0.00%)      -286,000 (-24.68%)
# B01272 - 富銀證券(香港)有限公司                         5,585,765 (0.01%)       5,289,765 (0.01%)       -296,000 (-5.30%)
# B01904 - 華盛資本証券有限公司                           4,421,629 (0.00%)       4,120,329 (0.00%)       -301,300 (-6.81%)
# B01353 - 大華繼顯(香港)有限公司                        26,542,622 (0.05%)      26,223,273 (0.05%)       -319,349 (-1.20%)
# B01413 - 京華山一國際(香港)有限公司                     1,577,000 (0.00%)       1,213,000 (0.00%)      -364,000 (-23.08%)
# C00074 - 德意志銀行                                    17,651,305 (0.03%)      17,180,259 (0.03%)       -471,046 (-2.67%)
# B01345 - 輝立証券(香港)有限公司                        16,797,336 (0.03%)      16,325,336 (0.03%)       -472,000 (-2.81%)
# B01825 - 國元証券經紀(香港)有限公司                    24,346,000 (0.05%)      23,870,000 (0.05%)       -476,000 (-1.96%)
# B01183 - 創興證券有限公司                               6,384,000 (0.01%)       5,900,000 (0.01%)       -484,000 (-7.58%)
# B02099 - 直達國際金融服務有限公司                         517,000 (0.00%)           2,000 (0.00%)      -515,000 (-99.61%)
# B01118 - 東亞證券有限公司                              10,760,919 (0.02%)      10,212,052 (0.02%)       -548,867 (-5.10%)
# B01264 - 馬銀證券(香港)有限公司                         3,314,864 (0.00%)       2,710,864 (0.00%)      -604,000 (-18.22%)
# B01948 - 財通國際證券有限公司                             886,000 (0.00%)         190,000 (0.00%)      -696,000 (-78.56%)
# C00040 - 中國工商銀行(亞洲)有限公司                   162,187,117 (0.34%)     161,444,117 (0.33%)       -743,000 (-0.46%)
# B01890 - 國信證券(香港)經紀有限公司                     2,237,000 (0.00%)       1,458,000 (0.00%)      -779,000 (-34.82%)
# B01389 - 中融平和證券有限公司                           1,137,000 (0.00%)         271,000 (0.00%)      -866,000 (-76.17%)
# C00002 - 交通銀行信託有限公司                          32,500,608 (0.06%)      31,628,641 (0.06%)       -871,967 (-2.68%)
# B01514 - 高信證券有限公司                               3,099,000 (0.00%)       2,093,500 (0.00%)    -1,005,500 (-32.45%)
# B01115 - 申萬宏源證券(香港)有限公司                     8,988,000 (0.01%)       7,948,000 (0.01%)    -1,040,000 (-11.57%)
# B01086 - 光大證券投資服務(香港)有限公司                23,861,131 (0.05%)      22,803,556 (0.04%)     -1,057,575 (-4.43%)
# C00058 - 中信銀行(國際)有限公司                        12,218,929 (0.02%)      11,096,929 (0.02%)     -1,122,000 (-9.18%)
# C00018 - 恒生銀行有限公司                              79,496,404 (0.16%)      78,279,734 (0.16%)     -1,216,670 (-1.53%)
# B01491 - CREDIT SUISSE SECURITIES (HONG KONG) LTD       1,431,810 (0.00%)          19,376 (0.00%)    -1,412,434 (-98.65%)
# C00041 - 華僑銀行(香港)有限公司                        11,337,470 (0.02%)       9,903,703 (0.02%)    -1,433,767 (-12.65%)
# B01555 - ABN AMRO CLEARING HONG KONG LTD                1,550,314 (0.00%)          25,131 (0.00%)    -1,525,183 (-98.38%)
# B01686 - 第一上海證券有限公司                          22,297,954 (0.04%)      20,666,954 (0.04%)     -1,631,000 (-7.31%)
# B02141 - 新永安國際證券有限公司                         2,065,000 (0.00%)         222,000 (0.00%)    -1,843,000 (-89.25%)
# C00015 - 星展銀行(香港)有限公司                        32,042,097 (0.06%)      30,159,607 (0.06%)     -1,882,490 (-5.88%)
# C00095 - 瑞士盈豐銀行股份有限公司                       3,683,808 (0.00%)       1,756,188 (0.00%)    -1,927,620 (-52.33%)
# B01962 - 中信建投(國際)証券有限公司                     2,978,000 (0.00%)       1,009,000 (0.00%)    -1,969,000 (-66.12%)
# B01939 - 東吳證券國際經紀有限公司                       3,561,320 (0.00%)       1,335,320 (0.00%)    -2,226,000 (-62.50%)
# B01793 - 大亞證券有限公司                              10,036,000 (0.02%)       7,522,000 (0.01%)    -2,514,000 (-25.05%)
# B01148 - 招商證券(香港)有限公司                        32,513,000 (0.06%)      29,838,000 (0.06%)     -2,675,000 (-8.23%)
# B01668 - 耀才證券國際(香港)有限公司                    15,962,603 (0.03%)      13,136,603 (0.02%)    -2,826,000 (-17.70%)
# B01590 - 盈透證券香港有限公司                         279,925,092 (0.58%)     277,077,993 (0.58%)     -2,847,099 (-1.02%)
# B01130 - 中銀國際證券有限公司                          88,929,037 (0.18%)      85,503,840 (0.17%)     -3,425,197 (-3.85%)
# B01905 - 安信國際證券(香港)有限公司                     9,534,000 (0.02%)       5,841,000 (0.01%)    -3,693,000 (-38.74%)
# B01284 - 恒生證券有限公司                              75,589,497 (0.15%)      71,410,516 (0.15%)     -4,178,981 (-5.53%)
# B01376 - 大眾証券有限公司                               4,892,000 (0.01%)               0 (0.00%)   -4,892,000 (-100.00%)
# C00042 - 招商永隆銀行有限公司                          55,624,013 (0.11%)      50,441,244 (0.10%)     -5,182,769 (-9.32%)
# B01762 - 星展唯高達香港有限公司                        12,441,730 (0.02%)       6,471,730 (0.01%)    -5,970,000 (-47.98%)
# B01826 - 廣發証券(香港)經紀有限公司                    10,529,000 (0.02%)       2,214,000 (0.00%)    -8,315,000 (-78.97%)
# B01451 - 高盛(亞洲)證券有限公司                        46,553,897 (0.09%)      35,681,930 (0.07%)   -10,871,967 (-23.35%)
# C00100 - JPMORGAN CHASE BANK, NATIONAL ASSOCIATION    163,255,291 (0.34%)     149,309,804 (0.31%)    -13,945,487 (-8.54%)
# C00033 - 中國銀行(香港)有限公司                       375,324,809 (0.78%)     354,326,059 (0.74%)    -20,998,750 (-5.59%)
# C00016 - DBS BANK LTD                                  78,604,387 (0.16%)      48,169,437 (0.10%)   -30,434,950 (-38.72%)
# B01274 - MORGAN STANLEY HONG KONG SECURITIES LTD      119,144,083 (0.25%)      87,705,779 (0.18%)   -31,438,304 (-26.39%)
# C00010 - 花旗銀行                                     249,838,275 (0.52%)     213,370,266 (0.44%)   -36,468,009 (-14.60%)
# C00019 - 香港上海匯豐銀行有限公司                   2,256,524,715 (4.74%)   2,110,998,891 (4.43%)   -145,525,824 (-6.45%)
# C00039 - 渣打銀行(香港)有限公司                     1,009,344,047 (2.12%)     802,705,072 (1.68%)  -206,638,975 (-20.47%)
# A00004 - CHINA SECURITIES DEPOSITORY AND CLEARING   3,832,109,539 (8.05%)   3,603,509,157 (7.57%)   -228,600,382 (-5.97%)
